# %%
import pandas as pd
import requests
import json
from pandas import json_normalize

# %%
immo = pd.read_csv('../immo_uni.csv')

# %%
immo
# Out:
#      Unnamed: 0          id  rent          street_number        lat       lng  \
# 0             0   108761792  1745      Berneggstrasse 28  47.420898  9.376225
# 1             1  2147994348  1720  Heiligkreuzstrasse 53  47.440407  9.393985
# 2             2  3000166218  1150       Lindenstrasse 76  47.433056  9.393829
# 3             3  3000251780  1390       Feldlistrasse 11  47.421700  9.356135
# 4             4  3000402506  2130        Goliathgasse 37  47.427975  9.377123
# ..          ...         ...   ...                    ...        ...       ...
# 480         544  3001465599  1240     Moosbruggstrasse 5  47.423676  9.379521
# 481         545  3001467270   890         Burgstrasse 80  47.417019  9.356454
# 482         546  3001468434  1660  Falkensteinstrasse 72  47.431427  9.398845
# 483         547  3001470695  1340            Höhenweg 13  47.429504  9.372371
# 484         548  3001470708  1835    Linsebühlstrasse 99  47.425991  9.385356
#
#            duration  duration_seconds  distance_meters
# 0    0:04:20.500000             260.5           2022.6
# 1    0:04:05.900000             245.9           2379.7
# 2    0:04:09.600000             249.6           1870.4
# 3    0:04:03.500000             243.5           2260.3
# 4    0:02:56.700000             176.7           1433.4
# ..              ...               ...              ...
# 480  0:03:21.600000             201.6           1823.4
# 481  0:04:30.300000             270.3           2502.4
# 482  0:05:26.100000             326.1           2493.9
# 483  0:01:47.300000             107.3            716.9
# 484  0:04:11.900000             251.9           2197.3
#
# [485 rows x 9 columns]

# %%
sm = pd.read_csv('../supermarkets.csv')

# %%
b = sm[sm.duration < 200].id.tolist()

# %%
immo
# Out:
#              id        lat       lng
# 0     108761792  47.420898  9.376225
# 1    2147994348  47.440407  9.393985
# 2    3000166218  47.433056  9.393829
# 3    3000251780  47.421700  9.356135
# 4    3000402506  47.427975  9.377123
# ..          ...        ...       ...
# 544  3001465599  47.423676  9.379521
# 545  3001467270  47.417019  9.356454
# 546  3001468434  47.431427  9.398845
# 547  3001470695  47.429504  9.372371
# 548  3001470708  47.425991  9.385356
#
# [549 rows x 3 columns]

# %%
a = immo[immo.distance_meters < 1000].id.tolist()

# %%
a
# Out:
# [3000922116,
#  3001118234,
#  3001235438,
#  3001246535,
#  3001286515,
#  3001350678,
#  3001352407,
#  3001370273,
#  3001405132,
#  3001416434,
#  3001416435,
#  3001416436,
#  3001421370,
#  3001467360,
#  3001465235,
#  3001441668,
#  3001441671,
#  3001441669,
#  3001442121,
#  3001470583,
#  3001470695]

# %%
res_id = set(a) & set(b)

# %%
immo[immo.id.isin(res_id)]
# Out:
#      Unnamed: 0          id  rent     street_number        lat       lng  \
# 16           16  3000922116  1454   Dianastrasse 10  47.432796  9.382410
# 55           62  3001118234  1140      Langgasse 11  47.434608  9.384761
# 113         124  3001246535  1820      Langgasse 11  47.434608  9.384761
# 235         255  3001350678  1695       Langgasse 9  47.434498  9.384642
# 237         257  3001352407  1515      Langgasse 13  47.434669  9.384833
# 346         390  3001421370  1340       Iddastrasse  47.435410  9.385141
# 352         396  3001467360  2630  Goethestrasse 44  47.436981  9.383111
# 371         420  3001465235  2630  Goethestrasse 44  47.436981  9.383111
# 415         465  3001441668  1285      Langgasse 11  47.434608  9.384761
# 416         466  3001441671  1990      Langgasse 11  47.434608  9.384761
# 417         467  3001441669  1815       Langgasse 9  47.434498  9.384642
# 456         509  3001442121  1550       Langgasse 5  47.434208  9.384363
# 469         522  3001470583  2150   Dufourstrasse 4  47.435242  9.383987
#
#            duration  duration_seconds  distance_meters
# 16   0:02:00.300000             120.3            746.8
# 55   0:02:28.600000             148.6            965.1
# 113  0:02:28.600000             148.6            965.1
# 235  0:02:29.700000             149.7            978.8
# 237  0:02:27.800000             147.8            956.5
# 346  0:02:29.900000             149.9            959.6
# 352         0:02:14             134.0            947.6
# 371         0:02:14             134.0            947.6
# 415  0:02:28.600000             148.6            965.1
# 416  0:02:28.600000             148.6            965.1
# 417  0:02:29.700000             149.7            978.8
# 456  0:02:29.700000             149.7            986.3
# 469  0:02:05.500000             125.5            837.0

# %%
r = requests.get('https://daten.stadt.sg.ch/api/records/1.0/search/?dataset=sammelstellen&q=&facet=abfallarten&geofilter.distance=47.4242%2C9.37186%2C1000 ')

# %%
res = json_normalize(json.loads(r.content)['records'])

# %%
res
# Out:
#        datasetid                                  recordid  \
# 0  sammelstellen  d87e7bf44a10b07d47d2de9d2e838126cf4de9a4
# 1  sammelstellen  7f77d95606dcc91a5cf0a6363055f728bbb8994e
# 2  sammelstellen  19cebea1cfdaed412fcb3da7a1eea1fb996796cf
# 3  sammelstellen  d5431b99c02570e6397bffea34b4bfe0850ce89f
# 4  sammelstellen  8f8b2f1af10e2fabbb5371213e5e7e4864373032
# 5  sammelstellen  abb9eba53e1a2702d58f9a8c5a2d8997d5d33a2b
# 6  sammelstellen  bf177dd1f3a293c1bd3c139ff94782060f5e83b0
# 7  sammelstellen  8d2670b237a921ed2514612aadec467bbf9c7301
# 8  sammelstellen  0cc16d649897a5bcb7b960e8d44b81442e3f741e
# 9  sammelstellen  aeb1cdda6abbb67018e109b6db616ac8af83f485
#
#                    record_timestamp                fields.standort  \
# 0  2021-11-06T05:30:13.768000+00:00                   Grabenpärkli
# 1  2021-11-06T05:30:13.768000+00:00      EKZ Neumarkt/Davidstrasse
# 2  2021-11-06T05:30:13.768000+00:00                Blumenbergplatz
# 3  2021-11-06T05:30:13.768000+00:00  Pic-o-Pello-Platz/Wallstrasse
# 4  2021-11-06T05:30:13.768000+00:00          Untere Büschenstrasse
# 5  2021-11-06T05:30:13.768000+00:00                        Mühlegg
# 6  2021-11-06T05:30:13.768000+00:00                   Schorenplatz
# 7  2021-11-06T05:30:13.768000+00:00          Güterbahnhofstrasse 6
# 8  2021-11-06T05:30:13.768000+00:00                Spelteriniplatz
# 9  2021-11-06T05:30:13.768000+00:00               Teufener Strasse
#
#                      fields.abfallarten    fields.dist  \
# 0                Aluminium; Dosen; Glas  154.933847985
# 1                Aluminium; Dosen; Glas   320.01335498
# 2                Aluminium; Dosen; Glas  360.907594215
# 3                Aluminium; Dosen; Glas  464.486890748
# 4                Aluminium; Dosen; Glas  790.964618541
# 5                Aluminium; Dosen; Glas  791.175739504
# 6  Aluminium; Dosen; Glas; Alttextilien  872.153930236
# 7            Altmetall; Altöl; Styropor  884.649429198
# 8                Aluminium; Dosen; Glas  899.068048762
# 9  Aluminium; Dosen; Glas; Alttextilien  963.571921957
#
#               fields.geo_point_2d fields.sammelstel geometry.type  \
# 0  [47.4245138419, 9.37386661488]                15         Point
# 1   [47.421329851, 9.37154776537]                11         Point
# 2  [47.4270900603, 9.37404359552]                14         Point
# 3  [47.4219372479, 9.37704974523]                16         Point
# 4   [47.425971119, 9.38204296726]                19         Point
# 5  [47.4195374829, 9.37980372379]                18         Point
# 6   [47.425747469, 9.36049465796]                13         Point
# 7    [47.4182230326, 9.364099448]                32         Point
# 8  [47.4296223711, 9.38072555514]                21         Point
# 9  [47.4163663494, 9.36638448777]                10         Point
#
#              geometry.coordinates fields.oeffnungsz
# 0  [9.37386661488, 47.4245138419]               NaN
# 1   [9.37154776537, 47.421329851]               NaN
# 2  [9.37404359552, 47.4270900603]               NaN
# 3  [9.37704974523, 47.4219372479]               NaN
# 4   [9.38204296726, 47.425971119]               NaN
# 5  [9.37980372379, 47.4195374829]               NaN
# 6   [9.36049465796, 47.425747469]               NaN
# 7    [9.364099448, 47.4182230326]       08.00-17.00
# 8  [9.38072555514, 47.4296223711]               NaN
# 9  [9.36638448777, 47.4163663494]               NaN
